# %% [markdown]
# "Guajira Guantananamera"
# En el municipio de Caimanera,en la provincia de Guantánamo vive Carmen,una muchacha que a pesar de haber nacido ahí y de que toda su familia,se encuentre viviendo allí.Su mayor deseo es emigrar.A medida que ha pasado el tiempo ,ella cada vez tiene más claro que su futuro no lo quiere en Caimanera.La familia de Carmen vive de la agricultura,y pues a ella no le llama la atención.Su deseo es emigrar hacia La Habana,pues dado que es la capital del país ,allí tendría mejores condiciones de vida y mayores oportunidades de empleo,con mejores salarios.
#
# ¿Solamente Carmen será la única que se siente incorforme con las condiciones de vida en su municipio y desea emigrar?
# Pues a lo largo de los años muchas personas han decidido emigrar ya sea hacia otro municipio,fuera de su provincia o incluso fuera del país.Desde 1989, Guantánamo presenta cada año la peor tasa migratoria interna del país. En el 2017, todos sus municipios tenían saldo migratorio negativo.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
 #Data Coordinates
x = np.array([2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]) 
y1 = np.array([-3350,-3938,-3618,-3336,-4837,-4693,-4400,-4419,-4070,-1959,-2525,-3882])
#y2 =np.array([6.6,-7.8,-7,-6.5,-9.4,-9.1,-8.6,-8.7,-8,-3.9,-5,-7.7])
# PLot])
plt.plot(x, y1) 
#plt.plot(x, y2) 

# Add Title
plt.title("Guantánamo") 
# Add Axes Labels
plt.xlabel("Años desde 2011 al 2022") 
plt.ylabel("Saldo migratorio Interno") 
# Display
plt.show()

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
 #Data Coordinates
x = np.array([2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]) 
y1 =np.array([6.6,-7.8,-7,-6.5,-9.4,-9.1,-8.6,-8.7,-8,-3.9,-5,-7.7])

# PLot])
plt.plot(x, y1) 


# Add Title
plt.title("Guantánamo") 
# Add Axes Labels
plt.xlabel("Años desde 2011 al 2022") 
plt.ylabel("Tasa de migración interna") 

# Display
plt.show()

# %% [markdown]
# Desde que Carmen era pequeña ha sido testigo de que la mayoría de sus vecinos han tomado la decisión de emigrar fuera de la provincia .

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
 #Data Coordinates
x = np.array([2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]) 
y1 =np.array([-1.5,-1.4,0.1,0.4,-0.6,-1.1,-0.7,-0.6,-0.4,-0.2,-0.1,0])

# PLot])
plt.plot(x, y1) 

# Add Title

plt.title("Guantánamo") 

# Add Axes Labels
plt.xlabel("Años desde 2011 al 2022") 
plt.ylabel("Tasa de migración Externa") 

# Display
plt.show()

# %% [markdown]
# En la tabla se puede apreciar que solamente en dos años ha sido positiva la tasa de migración externa ,mientras que en el resto de los años la tendencia en la tasa de migración externa fue negativa.Esto demuestra que las personas de Guantánamo optan por la migración interna.
