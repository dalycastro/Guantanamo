# %%
import pandas as pd
df = pd.read_csv('D:\\Ttrabajo de\\sexo-pp.csv')
print(df)
# Out:
#    PROVINCIAS DE  PROCEDENCIA   2011   2012   2013   2014   2015   2016  \
# 0                        Cuba  2,012  1,739  1,896  1,267  2,118  2,281
# 1                     Hombres  1,021    876    930    625  1,137  1,202
# 2                     Mujeres    991    863    966    642    981  1,079
# 3               Pinar del Río     33     29     35     13     11     22
# 4                     Hombres     15     16     18      6      8     10
# 5                     Mujeres     18     13     17      7      3     12
# 6                    Artemisa     82     60     88     74     95    112
# 7                     Hombres     52     35     46     38     57     67
# 8                     Mujeres     30     25     42     36     38     45
# 9                   La Habana    221    176    291    184    410    380
# 10                    Hombres    123    105    156    110    260    244
# 11                    Mujeres     98     71    135     74    150    136
# ...
